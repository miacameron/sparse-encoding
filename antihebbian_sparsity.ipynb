# %%
import numpy as np
import matplotlib.pyplot as plt
from utils import generate_lines_input

from plotting import plot_lines, plot_compare, plot_input, plot_weights, plot_digits, plot_compare_digits, plot_digit
import gzip

from oln import oln
from foldiak import anti_hebbian
import pickle

# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
lines = generate_lines_input(100)
plot_lines(lines[:8])

X = np.reshape(lines, (lines.shape[0], lines.shape[1]**2))

# %%
model = anti_hebbian(16, 64)
print(model.t)
model.train_thresholds(X, 400)
print(model.t)

# %%
model.train(X, 400)

# %%
plt.imshow(model.W)
plt.colorbar()

# %%
r0 = model.run(100, X[2])

# %%
print(r0)

# %% [markdown]
# With MNIST

# %%
src = "../data/train-images-idx3-ubyte.gz"
with gzip.open(src, 'rb') as f:
    data = np.frombuffer(f.read(), np.uint8, offset=16).reshape(-1, 28, 28)
X = data.reshape(data.shape[0], 28*28).astype(np.float64)

for t in range(X.shape[0]):
    if (np.linalg.norm(X[t]) != 0):
        X[t] = (X[t] - np.min(X[t])) / (np.max(X[t]) - np.min(X[t]))


plot_digits(X[:8])

# %%
model = anti_hebbian(784, 784)
model.train_thresholds(X[:200], 10)
# Out:
# epoch 0
# epoch 1
# epoch 2
# epoch 3
# epoch 4
# epoch 5
# epoch 6
# epoch 7
# epoch 8
# epoch 9

# %%
model.cyc = 100
model.tau = 0.02
model.train(X[:200], 500)
# Out:
# epoch 0
# epoch 1
# epoch 2
# epoch 3
# epoch 4
# epoch 5
# epoch 6
# epoch 7
# epoch 8
# epoch 9
# epoch 10
# epoch 11
# epoch 12
# epoch 13
# epoch 14
# epoch 15
# epoch 16
# epoch 17
# epoch 18
# epoch 19
# epoch 20
# epoch 21
# epoch 22
# epoch 23
# epoch 24
# epoch 25
# epoch 26
# epoch 27
# epoch 28
# epoch 29
# epoch 30
# epoch 31
# epoch 32
# epoch 33
# epoch 34
# epoch 35
# epoch 36
# epoch 37
# epoch 38
# epoch 39
# epoch 40
# epoch 41
# epoch 42
# epoch 43
# epoch 44
# epoch 45
# epoch 46
# epoch 47
# epoch 48
# epoch 49
# epoch 50
# epoch 51
# epoch 52
# epoch 53
# epoch 54
# epoch 55
# epoch 56
# epoch 57
# epoch 58
# epoch 59
# epoch 60
# epoch 61
# epoch 62
# epoch 63
# epoch 64
# epoch 65
# epoch 66
# epoch 67
# epoch 68
# epoch 69
# epoch 70
# epoch 71
# epoch 72
# epoch 73
# epoch 74
# epoch 75
# epoch 76
# epoch 77
# epoch 78
# epoch 79
# epoch 80
# epoch 81
# epoch 82
# epoch 83
# epoch 84
# epoch 85
# epoch 86
# epoch 87
# epoch 88
# epoch 89
# epoch 90
# ...

# %%
with open('./test_rnn_capacity/antihebbian_model.pkl', 'wb') as f:
    pickle.dump(model, f)

# %%
plt.imshow(model.W)
plt.colorbar()
plt.show()

# %%
model = anti_hebbian(784, 784)
model.cyc = 20
model.tau = 0.1
model.W = np.load('model_W.npy')
model.Q = np.load('model_Q.npy')
model.t = np.load('model_t.npy')

Y = model.encode_inputs(X[:100])
plot_digits(Y[8:16])

# %%
np.save('model_W.npy', model.W)
np.save('model_Q.npy', model.Q)
np.save('model_t.npy', model.t)

# %%
decoder = oln(Y, X[:100], 0.005, 8000, linear=False) 
decoder.run()

# %%
plt.imshow((decoder.W).reshape(784,784))
plt.colorbar()
#plt.clim(-0.1,0.1)
plt.show()

# %%
x_reconstructed = np.zeros((8, X.shape[1]))

for i in range(8):
    x_reconstructed[i] = decoder.sigmoid( decoder.W @ Y[i] )

plot_digits(x_reconstructed)

# %%
plt.plot(decoder.error_hist[10:], color='b')
#plt.yscale('log')
plt.show()

# %%
np.save('decoder_W.npy', decoder.W)
